# %%
using ReinforcementLearning
using Flux
using Statistics
using Plots

# %%
L=[NNlib.relu, NNlib.σ, NNlib.celu, NNlib.lisht, identity, NNlib.hardsigmoid, NNlib.hardtanh, NNlib.softplus,
   NNlib.swish, NNlib.logcosh];
B=32
# Out:
# 32

# %%
Env = CartPoleEnv(;T=Float32, seed=0)
Obs=observe(Env)
# Out:
# (reward = 1.0f0, terminal = false, state = Float32[0.027436066, 0.04111881, -0.026205778, 0.036788408])

# %%
subnetwork1,score=weakLearner(4,2,3,1,[],50)
# Out:
# (Dense{F,Array{Float32,2},Array{Float32,1}} where F[Dense(4, 32, lisht), Dense(32, 32, softplus), Dense(32, 32), Dense(32, 2, σ)], 8.58f0)

# %%
test=DQN(0.99,0.05,64,100000,4,2,1.0,10,[subnetwork1],1,1);

# %%
test.applyNets([0.027436066, 0.04111881, -0.026205778, 0.036788408])
# Out:
# 2-element Array{Float32,1}:
#  0.42519915
#  0.31076455

# %%
main_DQN(test,Env) #--> ne marche pas, résoudre pb loss function
# Out:
# 100 Last 100 episodes mean score: 9.28
# 200 Last 100 episodes mean score: 8.61
# 300 Last 100 episodes mean score: 8.43
# 400 Last 100 episodes mean score: 8.73
# 500 Last 100 episodes mean score: 8.62
# 600 Last 100 episodes mean score: 8.64
# 700 Last 100 episodes mean score: 8.5
# 800 Last 100 episodes mean score: 8.5
# 900 Last 100 episodes mean score: 8.62
# 1000 Last 100 episodes mean score: 8.63
# 1100 Last 100 episodes mean score: 8.55
# 1200 Last 100 episodes mean score: 8.75
# 1300 Last 100 episodes mean score: 8.66
# 1400 Last 100 episodes mean score: 8.79
# 1500 Last 100 episodes mean score: 8.51
# 1600 Last 100 episodes mean score: 8.67
# 1700 Last 100 episodes mean score: 8.72
# 1800 Last 100 episodes mean score: 8.63
# 1900 Last 100 episodes mean score: 8.5
# 2000 Last 100 episodes mean score: 8.74
# 2100 Last 100 episodes mean score: 8.75
# 2200 Last 100 episodes mean score: 8.5
# 2300 Last 100 episodes mean score: 8.57
# 2400 Last 100 episodes mean score: 8.59
# 2500 Last 100 episodes mean score: 8.73
# 2600 Last 100 episodes mean score: 8.57
# 2700 Last 100 episodes mean score: 8.54
# 2800 Last 100 episodes mean score: 8.47
# 2900 Last 100 episodes mean score: 8.67
# 3000 Last 100 episodes mean score: 8.6
# 3100 Last 100 episodes mean score: 8.65
# 3200 Last 100 episodes mean score: 8.58
# 3300 Last 100 episodes mean score: 8.78
# 3400 Last 100 episodes mean score: 8.67
# 3500 Last 100 episodes mean score: 8.72
# 3600 Last 100 episodes mean score: 8.59
# 3700 Last 100 episodes mean score: 8.46
# 3800 Last 100 episodes mean score: 8.63
# 3900 Last 100 episodes mean score: 8.57
# 4000 Last 100 episodes mean score: 8.72
# 4100 Last 100 episodes mean score: 8.52
# 4200 Last 100 episodes mean score: 8.65
# 4300 Last 100 episodes mean score: 8.7
# 4400 Last 100 episodes mean score: 8.59
# 4500 Last 100 episodes mean score: 8.46
# 4600 Last 100 episodes mean score: 8.68
# 4700 Last 100 episodes mean score: 8.69
# 4800 Last 100 episodes mean score: 8.7
# 4900 Last 100 episodes mean score: 8.84
# 5000 Last 100 episodes mean score: 8.5
# 5100 Last 100 episodes mean score: 8.52
# 5200 Last 100 episodes mean score: 8.65
# 5300 Last 100 episodes mean score: 8.72
# 5400 Last 100 episodes mean score: 8.64
# 5500 Last 100 episodes mean score: 8.75
# 5600 Last 100 episodes mean score: 8.57
# 5700 Last 100 episodes mean score: 8.61
# 5800 Last 100 episodes mean score: 8.61
# 5900 Last 100 episodes mean score: 8.68
# 6000 Last 100 episodes mean score: 8.58
# 6100 Last 100 episodes mean score: 8.53
# 6200 Last 100 episodes mean score: 8.61
# 6300 Last 100 episodes mean score: 8.63
# 6400 Last 100 episodes mean score: 8.71
# 6500 Last 100 episodes mean score: 8.64
# 6600 Last 100 episodes mean score: 8.72
# 6700 Last 100 episodes mean score: 8.54
# 6800 Last 100 episodes mean score: 8.67
# 6900 Last 100 episodes mean score: 8.52
# 7000 Last 100 episodes mean score: 8.69
# 7100 Last 100 episodes mean score: 8.56
# 7200 Last 100 episodes mean score: 8.64
# 7300 Last 100 episodes mean score: 8.72
# 7400 Last 100 episodes mean score: 8.67
# 7500 Last 100 episodes mean score: 8.57
# 7600 Last 100 episodes mean score: 8.6
# 7700 Last 100 episodes mean score: 8.63
# 7800 Last 100 episodes mean score: 8.44
# 7900 Last 100 episodes mean score: 8.74
# 8000 Last 100 episodes mean score: 8.61
# 8100 Last 100 episodes mean score: 8.61
# 8200 Last 100 episodes mean score: 8.68
# 8300 Last 100 episodes mean score: 8.58
# 8400 Last 100 episodes mean score: 8.57
# 8500 Last 100 episodes mean score: 8.66
# 8600 Last 100 episodes mean score: 8.72
# 8700 Last 100 episodes mean score: 8.6
# 8800 Last 100 episodes mean score: 8.56
# 8900 Last 100 episodes mean score: 8.61
# 9000 Last 100 episodes mean score: 8.6
# 9100 Last 100 episodes mean score: 8.56
# 9200 Last 100 episodes mean score: 8.64
# 9300 Last 100 episodes mean score: 8.66
# 9400 Last 100 episodes mean score: 8.7
# 9500 Last 100 episodes mean score: 8.59
# 9600 Last 100 episodes mean score: 8.88
# 9700 Last 100 episodes mean score: 8.73
# 9800 Last 100 episodes mean score: 8.37
# 9900 Last 100 episodes mean score: 8.74
# 10000 Last 100 episodes mean score: 8.6
# 10100 Last 100 episodes mean score: 8.6
# 10200 Last 100 episodes mean score: 8.6
# 10300 Last 100 episodes mean score: 8.54
# 10400 Last 100 episodes mean score: 8.45
# 10500 Last 100 episodes mean score: 8.74
# 10600 Last 100 episodes mean score: 8.49
# 10700 Last 100 episodes mean score: 8.57
# 10800 Last 100 episodes mean score: 8.62
# 10900 Last 100 episodes mean score: 8.67
# 11000 Last 100 episodes mean score: 8.59
# 11100 Last 100 episodes mean score: 8.53
# 11200 Last 100 episodes mean score: 8.71
# 11300 Last 100 episodes mean score: 8.71
# 11400 Last 100 episodes mean score: 8.57
# 11500 Last 100 episodes mean score: 8.74
# 11600 Last 100 episodes mean score: 8.76
# 11700 Last 100 episodes mean score: 8.42
# 11800 Last 100 episodes mean score: 8.88
# 11900 Last 100 episodes mean score: 8.62
# 12000 Last 100 episodes mean score: 8.66
# 12100 Last 100 episodes mean score: 8.6
# 12200 Last 100 episodes mean score: 8.6
# 12300 Last 100 episodes mean score: 8.72
# 12400 Last 100 episodes mean score: 8.47
# 12500 Last 100 episodes mean score: 8.45
# 12600 Last 100 episodes mean score: 8.53
# 12700 Last 100 episodes mean score: 8.63
# 12800 Last 100 episodes mean score: 8.62
# 12900 Last 100 episodes mean score: 8.53
# 13000 Last 100 episodes mean score: 8.8
# 13100 Last 100 episodes mean score: 8.64
# 13200 Last 100 episodes mean score: 8.43
# 13300 Last 100 episodes mean score: 8.45
# 13400 Last 100 episodes mean score: 8.5
# 13500 Last 100 episodes mean score: 8.82
# 13600 Last 100 episodes mean score: 8.48
# 13700 Last 100 episodes mean score: 8.55
# 13800 Last 100 episodes mean score: 8.8
# 13900 Last 100 episodes mean score: 8.47
# 14000 Last 100 episodes mean score: 8.55
# 14100 Last 100 episodes mean score: 8.62
# 14200 Last 100 episodes mean score: 8.64
# 14300 Last 100 episodes mean score: 8.88
# 14400 Last 100 episodes mean score: 8.64
# 14500 Last 100 episodes mean score: 8.58
# 14600 Last 100 episodes mean score: 8.59
# 14700 Last 100 episodes mean score: 8.7
# 14800 Last 100 episodes mean score: 8.71
# 14900 Last 100 episodes mean score: 8.67
# 15000 Last 100 episodes mean score: 8.51
# 15100 Last 100 episodes mean score: 8.65
# 15200 Last 100 episodes mean score: 8.41
# 15300 Last 100 episodes mean score: 8.48
# 15400 Last 100 episodes mean score: 8.66
# 15500 Last 100 episodes mean score: 8.57
# 15600 Last 100 episodes mean score: 8.4
# 15700 Last 100 episodes mean score: 8.5
# 15800 Last 100 episodes mean score: 8.69
# 15900 Last 100 episodes mean score: 8.61
# 16000 Last 100 episodes mean score: 8.53
# 16100 Last 100 episodes mean score: 8.59
# 16200 Last 100 episodes mean score: 8.53
# 16300 Last 100 episodes mean score: 8.63
# 16400 Last 100 episodes mean score: 8.64
# 16500 Last 100 episodes mean score: 8.47
# 16600 Last 100 episodes mean score: 8.62
# 16700 Last 100 episodes mean score: 8.57
# 16800 Last 100 episodes mean score: 8.53
# 16900 Last 100 episodes mean score: 8.83
# 17000 Last 100 episodes mean score: 8.53
# 17100 Last 100 episodes mean score: 8.71
# 17200 Last 100 episodes mean score: 8.43
# 17300 Last 100 episodes mean score: 8.67
# 17400 Last 100 episodes mean score: 8.46
# 17500 Last 100 episodes mean score: 8.8
# 17600 Last 100 episodes mean score: 8.57
# 17700 Last 100 episodes mean score: 8.52
# 17800 Last 100 episodes mean score: 8.59
# 17900 Last 100 episodes mean score: 8.54
# 18000 Last 100 episodes mean score: 8.69
# 18100 Last 100 episodes mean score: 8.71
# 18200 Last 100 episodes mean score: 8.59
# 18300 Last 100 episodes mean score: 8.69
# 18400 Last 100 episodes mean score: 8.48
# 18500 Last 100 episodes mean score: 8.5
# 18600 Last 100 episodes mean score: 8.57
# 18700 Last 100 episodes mean score: 8.7
# 18800 Last 100 episodes mean score: 8.73
# 18900 Last 100 episodes mean score: 8.5
# 19000 Last 100 episodes mean score: 8.57
# 19100 Last 100 episodes mean score: 8.44
# 19200 Last 100 episodes mean score: 8.36
# 19300 Last 100 episodes mean score: 8.45
# 19400 Last 100 episodes mean score: 8.61
# 19500 Last 100 episodes mean score: 8.81
# 19600 Last 100 episodes mean score: 8.51
# 19700 Last 100 episodes mean score: 8.65
# 19800 Last 100 episodes mean score: 8.51
# 19900 Last 100 episodes mean score: 8.64
# 20000 Last 100 episodes mean score: 8.61
# 20100 Last 100 episodes mean score: 8.68
# 20200 Last 100 episodes mean score: 8.92
# 20300 Last 100 episodes mean score: 8.61
# 20400 Last 100 episodes mean score: 8.67
# 20500 Last 100 episodes mean score: 8.61
# 20600 Last 100 episodes mean score: 8.55
# 20700 Last 100 episodes mean score: 8.37
# 20800 Last 100 episodes mean score: 8.53
# 20900 Last 100 episodes mean score: 8.64
# 21000 Last 100 episodes mean score: 8.63
# 21100 Last 100 episodes mean score: 8.7
# 21200 Last 100 episodes mean score: 8.68
# 21300 Last 100 episodes mean score: 8.55
# 21400 Last 100 episodes mean score: 8.62
# 21500 Last 100 episodes mean score: 8.49
# 21600 Last 100 episodes mean score: 8.42
# 21700 Last 100 episodes mean score: 8.59
# 21800 Last 100 episodes mean score: 8.49
# 21900 Last 100 episodes mean score: 8.68
# 22000 Last 100 episodes mean score: 8.5
# 22100 Last 100 episodes mean score: 8.72
# 22200 Last 100 episodes mean score: 8.69
# 22300 Last 100 episodes mean score: 8.7
# 22400 Last 100 episodes mean score: 8.78
# 22500 Last 100 episodes mean score: 8.54
# 22600 Last 100 episodes mean score: 8.63
# 22700 Last 100 episodes mean score: 8.52
# 22800 Last 100 episodes mean score: 8.51
# 22900 Last 100 episodes mean score: 8.73
# 23000 Last 100 episodes mean score: 8.69
# 23100 Last 100 episodes mean score: 8.68
# 23200 Last 100 episodes mean score: 8.6
# 23300 Last 100 episodes mean score: 8.65
# 23400 Last 100 episodes mean score: 8.66
# 23500 Last 100 episodes mean score: 8.5
# 23600 Last 100 episodes mean score: 8.52
# 23700 Last 100 episodes mean score: 8.44
# 23800 Last 100 episodes mean score: 8.49
# 23900 Last 100 episodes mean score: 8.61
# 24000 Last 100 episodes mean score: 8.6
# 24100 Last 100 episodes mean score: 8.7
# 24200 Last 100 episodes mean score: 8.63
# 24300 Last 100 episodes mean score: 8.71
# 24400 Last 100 episodes mean score: 8.62
# 24500 Last 100 episodes mean score: 8.69
# 24600 Last 100 episodes mean score: 8.75
# 24700 Last 100 episodes mean score: 8.65
# 24800 Last 100 episodes mean score: 8.59
# 24900 Last 100 episodes mean score: 8.74
# 25000 Last 100 episodes mean score: 8.49
# 25100 Last 100 episodes mean score: 8.64
# 25200 Last 100 episodes mean score: 8.58
# 25300 Last 100 episodes mean score: 8.72
# 25400 Last 100 episodes mean score: 8.53
# 25500 Last 100 episodes mean score: 8.57
# 25600 Last 100 episodes mean score: 8.59
# 25700 Last 100 episodes mean score: 8.64
# 25800 Last 100 episodes mean score: 8.72
# 25900 Last 100 episodes mean score: 8.76
# 26000 Last 100 episodes mean score: 8.62
# 26100 Last 100 episodes mean score: 8.6
# 26200 Last 100 episodes mean score: 8.58
# 26300 Last 100 episodes mean score: 8.56
# 26400 Last 100 episodes mean score: 8.67
# 26500 Last 100 episodes mean score: 8.52
# 26600 Last 100 episodes mean score: 8.65
# 26700 Last 100 episodes mean score: 8.51
# 26800 Last 100 episodes mean score: 8.61
# 26900 Last 100 episodes mean score: 8.7
# 27000 Last 100 episodes mean score: 8.57
# 27100 Last 100 episodes mean score: 8.61
# 27200 Last 100 episodes mean score: 8.54
# 27300 Last 100 episodes mean score: 8.7
# 27400 Last 100 episodes mean score: 8.57
# 27500 Last 100 episodes mean score: 8.56
# 27600 Last 100 episodes mean score: 8.72
# 27700 Last 100 episodes mean score: 8.53
# 27800 Last 100 episodes mean score: 8.47
# 27900 Last 100 episodes mean score: 8.56
# 28000 Last 100 episodes mean score: 8.63
# 28100 Last 100 episodes mean score: 8.42
# 28200 Last 100 episodes mean score: 8.66
# 28300 Last 100 episodes mean score: 8.75
# 28400 Last 100 episodes mean score: 8.56
# 28500 Last 100 episodes mean score: 8.47
# 28600 Last 100 episodes mean score: 8.83
# 28700 Last 100 episodes mean score: 8.61
# 28800 Last 100 episodes mean score: 8.67
# 28900 Last 100 episodes mean score: 8.73
# 29000 Last 100 episodes mean score: 8.63
# 29100 Last 100 episodes mean score: 8.55
# 29200 Last 100 episodes mean score: 8.49
# 29300 Last 100 episodes mean score: 8.7
# 29400 Last 100 episodes mean score: 8.75
# 29500 Last 100 episodes mean score: 8.59
# 29600 Last 100 episodes mean score: 8.71
# 29700 Last 100 episodes mean score: 8.56
# 29800 Last 100 episodes mean score: 8.53
# 29900 Last 100 episodes mean score: 8.76
# 30000 Last 100 episodes mean score: 8.53
# 30100 Last 100 episodes mean score: 8.55
# 30200 Last 100 episodes mean score: 8.59
# 30300 Last 100 episodes mean score: 8.58
# 30400 Last 100 episodes mean score: 8.65
# 30500 Last 100 episodes mean score: 8.55
# 30600 Last 100 episodes mean score: 8.74
# 30700 Last 100 episodes mean score: 8.64
# 30800 Last 100 episodes mean score: 8.66
# 30900 Last 100 episodes mean score: 8.75
# 31000 Last 100 episodes mean score: 8.48
# 31100 Last 100 episodes mean score: 8.72
# 31200 Last 100 episodes mean score: 8.47
# 31300 Last 100 episodes mean score: 8.61
# 31400 Last 100 episodes mean score: 8.58
# 31500 Last 100 episodes mean score: 8.73
# 31600 Last 100 episodes mean score: 8.67
# 31700 Last 100 episodes mean score: 8.56
# 31800 Last 100 episodes mean score: 8.58
# 31900 Last 100 episodes mean score: 8.68
# 32000 Last 100 episodes mean score: 8.6
# 32100 Last 100 episodes mean score: 8.45
# 32200 Last 100 episodes mean score: 8.79
# 32300 Last 100 episodes mean score: 8.7
# 32400 Last 100 episodes mean score: 8.57
# 32500 Last 100 episodes mean score: 8.72
# 32600 Last 100 episodes mean score: 8.67
# 32700 Last 100 episodes mean score: 8.51
# 32800 Last 100 episodes mean score: 8.6
# 32900 Last 100 episodes mean score: 8.56
# 33000 Last 100 episodes mean score: 8.64
# 33100 Last 100 episodes mean score: 8.59
# 33200 Last 100 episodes mean score: 8.6
# 33300 Last 100 episodes mean score: 8.56
# 33400 Last 100 episodes mean score: 8.59
# 33500 Last 100 episodes mean score: 8.57
# 33600 Last 100 episodes mean score: 8.58
# 33700 Last 100 episodes mean score: 8.65
# 33800 Last 100 episodes mean score: 8.51
# 33900 Last 100 episodes mean score: 8.53
# 34000 Last 100 episodes mean score: 8.57
# 34100 Last 100 episodes mean score: 8.5
# 34200 Last 100 episodes mean score: 8.86
# 34300 Last 100 episodes mean score: 8.85
# 34400 Last 100 episodes mean score: 8.42
# 34500 Last 100 episodes mean score: 8.78
# 34600 Last 100 episodes mean score: 8.55
# 34700 Last 100 episodes mean score: 8.78
# 34800 Last 100 episodes mean score: 8.43
# 34900 Last 100 episodes mean score: 8.73
# 35000 Last 100 episodes mean score: 8.57
# 35100 Last 100 episodes mean score: 8.66
# 35200 Last 100 episodes mean score: 8.65
# 35300 Last 100 episodes mean score: 8.72
# 35400 Last 100 episodes mean score: 8.42
# 35500 Last 100 episodes mean score: 8.6
# 35600 Last 100 episodes mean score: 8.66
# 35700 Last 100 episodes mean score: 8.69
# 35800 Last 100 episodes mean score: 8.66
# 35900 Last 100 episodes mean score: 8.7
# 36000 Last 100 episodes mean score: 8.73
# 36100 Last 100 episodes mean score: 8.83
# 36200 Last 100 episodes mean score: 8.69
# 36300 Last 100 episodes mean score: 8.43
# 36400 Last 100 episodes mean score: 8.59
# 36500 Last 100 episodes mean score: 8.56
# 36600 Last 100 episodes mean score: 8.57
# 36700 Last 100 episodes mean score: 8.53
# 36800 Last 100 episodes mean score: 8.54
# 36900 Last 100 episodes mean score: 8.5
# 37000 Last 100 episodes mean score: 8.72
# 37100 Last 100 episodes mean score: 8.54
# 37200 Last 100 episodes mean score: 8.56
# 37300 Last 100 episodes mean score: 8.5
# 37400 Last 100 episodes mean score: 8.83
# 37500 Last 100 episodes mean score: 8.6
# 37600 Last 100 episodes mean score: 8.61
# 37700 Last 100 episodes mean score: 8.7
# 37800 Last 100 episodes mean score: 8.59
# 37900 Last 100 episodes mean score: 8.62
# 38000 Last 100 episodes mean score: 8.89
# 38100 Last 100 episodes mean score: 8.82
# 38200 Last 100 episodes mean score: 8.64
# 38300 Last 100 episodes mean score: 8.67
# 38400 Last 100 episodes mean score: 8.7
# 38500 Last 100 episodes mean score: 8.51
# 38600 Last 100 episodes mean score: 8.65
# 38700 Last 100 episodes mean score: 8.53
# 38800 Last 100 episodes mean score: 8.44
# 38900 Last 100 episodes mean score: 8.48
# 39000 Last 100 episodes mean score: 8.44
# 39100 Last 100 episodes mean score: 8.51
# 39200 Last 100 episodes mean score: 8.54
# 39300 Last 100 episodes mean score: 8.64
# 39400 Last 100 episodes mean score: 8.7
# 39500 Last 100 episodes mean score: 8.69
# 39600 Last 100 episodes mean score: 8.63
# 39700 Last 100 episodes mean score: 8.61
# 39800 Last 100 episodes mean score: 8.57
# 39900 Last 100 episodes mean score: 8.67
# 40000 Last 100 episodes mean score: 8.6
# 40100 Last 100 episodes mean score: 8.53
# 40200 Last 100 episodes mean score: 8.53
# 40300 Last 100 episodes mean score: 8.64
# 40400 Last 100 episodes mean score: 8.69
# 40500 Last 100 episodes mean score: 8.52
# 40600 Last 100 episodes mean score: 8.72
# 40700 Last 100 episodes mean score: 8.66
# 40800 Last 100 episodes mean score: 8.66
# 40900 Last 100 episodes mean score: 8.77
# 41000 Last 100 episodes mean score: 8.64
# 41100 Last 100 episodes mean score: 8.55
# 41200 Last 100 episodes mean score: 8.53
# 41300 Last 100 episodes mean score: 8.6
# 41400 Last 100 episodes mean score: 8.57
# 41500 Last 100 episodes mean score: 8.71
# 41600 Last 100 episodes mean score: 8.51
# 41700 Last 100 episodes mean score: 8.63
# 41800 Last 100 episodes mean score: 8.52
# 41900 Last 100 episodes mean score: 8.52
# 42000 Last 100 episodes mean score: 8.57
# 42100 Last 100 episodes mean score: 8.54
# 42200 Last 100 episodes mean score: 8.64
# 42300 Last 100 episodes mean score: 8.56
# 42400 Last 100 episodes mean score: 8.68
# 42500 Last 100 episodes mean score: 8.59
# 42600 Last 100 episodes mean score: 8.46
# 42700 Last 100 episodes mean score: 8.78
# 42800 Last 100 episodes mean score: 8.43
# 42900 Last 100 episodes mean score: 8.61
# 43000 Last 100 episodes mean score: 8.62
# 43100 Last 100 episodes mean score: 8.54
# 43200 Last 100 episodes mean score: 8.7
# 43300 Last 100 episodes mean score: 8.59
# 43400 Last 100 episodes mean score: 8.49
# 43500 Last 100 episodes mean score: 8.61
# 43600 Last 100 episodes mean score: 8.64
# 43700 Last 100 episodes mean score: 8.62
# 43800 Last 100 episodes mean score: 8.58
# 43900 Last 100 episodes mean score: 8.56
# 44000 Last 100 episodes mean score: 8.55
# 44100 Last 100 episodes mean score: 8.5
# 44200 Last 100 episodes mean score: 8.65
# 44300 Last 100 episodes mean score: 8.47
# 44400 Last 100 episodes mean score: 8.66
# 44500 Last 100 episodes mean score: 8.57
# 44600 Last 100 episodes mean score: 8.75
# 44700 Last 100 episodes mean score: 8.68
# 44800 Last 100 episodes mean score: 8.6
# 44900 Last 100 episodes mean score: 8.67
# 45000 Last 100 episodes mean score: 8.62
# 45100 Last 100 episodes mean score: 8.54
# 45200 Last 100 episodes mean score: 8.7
# 45300 Last 100 episodes mean score: 8.7
# 45400 Last 100 episodes mean score: 8.73
# 45500 Last 100 episodes mean score: 8.47
# 45600 Last 100 episodes mean score: 8.72
# 45700 Last 100 episodes mean score: 8.61
# 45800 Last 100 episodes mean score: 8.79
# 45900 Last 100 episodes mean score: 8.54
# 46000 Last 100 episodes mean score: 8.62
# 46100 Last 100 episodes mean score: 8.78
# 46200 Last 100 episodes mean score: 8.56
# 46300 Last 100 episodes mean score: 8.61
# 46400 Last 100 episodes mean score: 8.55
# 46500 Last 100 episodes mean score: 8.58
# 46600 Last 100 episodes mean score: 8.63
# 46700 Last 100 episodes mean score: 8.73
# 46800 Last 100 episodes mean score: 8.5
# 46900 Last 100 episodes mean score: 8.7
# 47000 Last 100 episodes mean score: 8.57
# 47100 Last 100 episodes mean score: 8.44
# 47200 Last 100 episodes mean score: 8.66
# 47300 Last 100 episodes mean score: 8.49
# 47400 Last 100 episodes mean score: 8.4
# 47500 Last 100 episodes mean score: 8.59
# 47600 Last 100 episodes mean score: 8.62
# 47700 Last 100 episodes mean score: 8.59
# 47800 Last 100 episodes mean score: 8.58
# 47900 Last 100 episodes mean score: 8.39
# 48000 Last 100 episodes mean score: 8.73
# 48100 Last 100 episodes mean score: 8.69
# 48200 Last 100 episodes mean score: 8.74
# 48300 Last 100 episodes mean score: 8.71
# 48400 Last 100 episodes mean score: 8.7
# 48500 Last 100 episodes mean score: 8.59
# 48600 Last 100 episodes mean score: 8.78
# 48700 Last 100 episodes mean score: 8.58
# 48800 Last 100 episodes mean score: 8.56
# 48900 Last 100 episodes mean score: 8.6
# 49000 Last 100 episodes mean score: 8.7
# 49100 Last 100 episodes mean score: 8.56
# 49200 Last 100 episodes mean score: 8.57
# 49300 Last 100 episodes mean score: 8.56
# 49400 Last 100 episodes mean score: 8.63
# 49500 Last 100 episodes mean score: 8.7
# 49600 Last 100 episodes mean score: 8.47
# 49700 Last 100 episodes mean score: 8.59
# 49800 Last 100 episodes mean score: 8.73
# 49900 Last 100 episodes mean score: 8.41
# 50000 Last 100 episodes mean score: 8.74
# 50100 Last 100 episodes mean score: 8.73
# 50200 Last 100 episodes mean score: 8.52
# 50300 Last 100 episodes mean score: 8.65
# 50400 Last 100 episodes mean score: 8.74
# 50500 Last 100 episodes mean score: 8.59
# 50600 Last 100 episodes mean score: 8.49
# 50700 Last 100 episodes mean score: 8.66
# 50800 Last 100 episodes mean score: 8.62
# 50900 Last 100 episodes mean score: 8.46
# 51000 Last 100 episodes mean score: 8.67
# 51100 Last 100 episodes mean score: 8.63
# 51200 Last 100 episodes mean score: 8.69
# 51300 Last 100 episodes mean score: 8.59
# 51400 Last 100 episodes mean score: 8.58
# 51500 Last 100 episodes mean score: 8.62
# 51600 Last 100 episodes mean score: 8.73
# 51700 Last 100 episodes mean score: 8.56
# 51800 Last 100 episodes mean score: 8.72
# 51900 Last 100 episodes mean score: 8.79
# 52000 Last 100 episodes mean score: 8.58
# 52100 Last 100 episodes mean score: 8.49
# 52200 Last 100 episodes mean score: 8.54
# 52300 Last 100 episodes mean score: 8.52
# 52400 Last 100 episodes mean score: 8.82
# 52500 Last 100 episodes mean score: 8.76
# 52600 Last 100 episodes mean score: 8.52
# 52700 Last 100 episodes mean score: 8.61
# 52800 Last 100 episodes mean score: 8.55
# 52900 Last 100 episodes mean score: 8.58
# 53000 Last 100 episodes mean score: 8.76
# 53100 Last 100 episodes mean score: 8.65
# 53200 Last 100 episodes mean score: 8.58
# 53300 Last 100 episodes mean score: 8.71
# 53400 Last 100 episodes mean score: 8.59
# 53500 Last 100 episodes mean score: 8.6
# 53600 Last 100 episodes mean score: 8.6
# 53700 Last 100 episodes mean score: 8.58
# 53800 Last 100 episodes mean score: 8.67
# 53900 Last 100 episodes mean score: 8.68
# 54000 Last 100 episodes mean score: 8.54
# 54100 Last 100 episodes mean score: 8.62
# 54200 Last 100 episodes mean score: 8.64
# 54300 Last 100 episodes mean score: 8.69
# 54400 Last 100 episodes mean score: 8.55
# 54500 Last 100 episodes mean score: 8.7
# 54600 Last 100 episodes mean score: 8.85
# 54700 Last 100 episodes mean score: 8.63
# 54800 Last 100 episodes mean score: 8.49
# 54900 Last 100 episodes mean score: 8.78
# 55000 Last 100 episodes mean score: 8.58
# 55100 Last 100 episodes mean score: 8.72
# 55200 Last 100 episodes mean score: 8.62
# 55300 Last 100 episodes mean score: 8.69
# 55400 Last 100 episodes mean score: 8.53
# 55500 Last 100 episodes mean score: 8.65
# 55600 Last 100 episodes mean score: 8.41
# 55700 Last 100 episodes mean score: 8.64
# 55800 Last 100 episodes mean score: 8.47
# 55900 Last 100 episodes mean score: 8.67
# 56000 Last 100 episodes mean score: 8.68
# 56100 Last 100 episodes mean score: 8.6
# 56200 Last 100 episodes mean score: 8.62
# 56300 Last 100 episodes mean score: 8.81
# 56400 Last 100 episodes mean score: 8.44
# 56500 Last 100 episodes mean score: 8.66
# 56600 Last 100 episodes mean score: 8.92
# 56700 Last 100 episodes mean score: 8.52
# 56800 Last 100 episodes mean score: 8.83
# 56900 Last 100 episodes mean score: 8.5
# 57000 Last 100 episodes mean score: 8.56
# 57100 Last 100 episodes mean score: 8.63
# 57200 Last 100 episodes mean score: 8.61
# 57300 Last 100 episodes mean score: 8.69
# 57400 Last 100 episodes mean score: 8.71
# 57500 Last 100 episodes mean score: 8.64
# 57600 Last 100 episodes mean score: 8.58
# 57700 Last 100 episodes mean score: 8.55
# 57800 Last 100 episodes mean score: 8.74
# 57900 Last 100 episodes mean score: 8.65
# 58000 Last 100 episodes mean score: 8.66
# 58100 Last 100 episodes mean score: 8.56
# 58200 Last 100 episodes mean score: 8.53
# 58300 Last 100 episodes mean score: 8.73
# 58400 Last 100 episodes mean score: 8.41
# 58500 Last 100 episodes mean score: 8.62
# 58600 Last 100 episodes mean score: 8.85
# 58700 Last 100 episodes mean score: 8.66
# 58800 Last 100 episodes mean score: 8.45
# 58900 Last 100 episodes mean score: 8.61
# 59000 Last 100 episodes mean score: 8.41
# 59100 Last 100 episodes mean score: 8.58
# 59200 Last 100 episodes mean score: 8.47
# 59300 Last 100 episodes mean score: 8.51
# 59400 Last 100 episodes mean score: 8.58
# 59500 Last 100 episodes mean score: 8.86
# 59600 Last 100 episodes mean score: 8.74
# 59700 Last 100 episodes mean score: 8.63
# 59800 Last 100 episodes mean score: 8.69
# 59900 Last 100 episodes mean score: 8.76
# 60000 Last 100 episodes mean score: 8.53
# 60100 Last 100 episodes mean score: 8.74
# 60200 Last 100 episodes mean score: 8.6
# 60300 Last 100 episodes mean score: 8.65
# 60400 Last 100 episodes mean score: 8.52
# 60500 Last 100 episodes mean score: 8.67
# 60600 Last 100 episodes mean score: 8.77
# 60700 Last 100 episodes mean score: 8.57
# 60800 Last 100 episodes mean score: 8.63
# 60900 Last 100 episodes mean score: 8.58
# 61000 Last 100 episodes mean score: 8.53
# 61100 Last 100 episodes mean score: 8.49
# 61200 Last 100 episodes mean score: 8.62
# 61300 Last 100 episodes mean score: 8.49
# 61400 Last 100 episodes mean score: 8.55
# 61500 Last 100 episodes mean score: 8.78
# 61600 Last 100 episodes mean score: 8.68
# 61700 Last 100 episodes mean score: 8.63
# 61800 Last 100 episodes mean score: 8.67
# 61900 Last 100 episodes mean score: 8.62
# 62000 Last 100 episodes mean score: 8.6
# 62100 Last 100 episodes mean score: 8.56
# 62200 Last 100 episodes mean score: 8.62
# 62300 Last 100 episodes mean score: 8.73
# 62400 Last 100 episodes mean score: 8.57
# 62500 Last 100 episodes mean score: 8.54
# 62600 Last 100 episodes mean score: 8.55
# 62700 Last 100 episodes mean score: 8.67
# 62800 Last 100 episodes mean score: 8.56
# 62900 Last 100 episodes mean score: 8.6
# 63000 Last 100 episodes mean score: 8.67
# 63100 Last 100 episodes mean score: 8.45
# 63200 Last 100 episodes mean score: 8.64
# 63300 Last 100 episodes mean score: 8.55
# 63400 Last 100 episodes mean score: 8.7
# 63500 Last 100 episodes mean score: 8.63
# 63600 Last 100 episodes mean score: 8.5
# 63700 Last 100 episodes mean score: 8.62
# 63800 Last 100 episodes mean score: 8.78
# 63900 Last 100 episodes mean score: 8.78
# 64000 Last 100 episodes mean score: 8.67
# 64100 Last 100 episodes mean score: 8.62
# 64200 Last 100 episodes mean score: 8.63
# 64300 Last 100 episodes mean score: 8.72
# 64400 Last 100 episodes mean score: 8.7
# 64500 Last 100 episodes mean score: 8.54
# 64600 Last 100 episodes mean score: 8.81
# 64700 Last 100 episodes mean score: 8.62
# 64800 Last 100 episodes mean score: 8.66
# 64900 Last 100 episodes mean score: 8.54
# 65000 Last 100 episodes mean score: 8.77
# 65100 Last 100 episodes mean score: 8.48
# 65200 Last 100 episodes mean score: 8.58
# 65300 Last 100 episodes mean score: 8.71
# 65400 Last 100 episodes mean score: 8.6
# 65500 Last 100 episodes mean score: 8.52
# 65600 Last 100 episodes mean score: 8.76
# 65700 Last 100 episodes mean score: 8.47
# 65800 Last 100 episodes mean score: 8.61
# 65900 Last 100 episodes mean score: 8.64
# 66000 Last 100 episodes mean score: 8.43
# 66100 Last 100 episodes mean score: 8.46
# 66200 Last 100 episodes mean score: 8.79
# 66300 Last 100 episodes mean score: 8.62
# 66400 Last 100 episodes mean score: 8.52
# 66500 Last 100 episodes mean score: 8.69
# 66600 Last 100 episodes mean score: 8.59
# 66700 Last 100 episodes mean score: 8.62
# 66800 Last 100 episodes mean score: 8.62
# 66900 Last 100 episodes mean score: 8.52
# 67000 Last 100 episodes mean score: 8.63
# 67100 Last 100 episodes mean score: 8.59
# 67200 Last 100 episodes mean score: 8.68
# 67300 Last 100 episodes mean score: 8.77
# 67400 Last 100 episodes mean score: 8.82
# 67500 Last 100 episodes mean score: 8.76
# 67600 Last 100 episodes mean score: 8.61
# 67700 Last 100 episodes mean score: 8.6
# 67800 Last 100 episodes mean score: 8.39
# 67900 Last 100 episodes mean score: 8.62
# 68000 Last 100 episodes mean score: 8.57
# 68100 Last 100 episodes mean score: 8.6
# 68200 Last 100 episodes mean score: 8.51
# 68300 Last 100 episodes mean score: 8.56
# 68400 Last 100 episodes mean score: 8.57
# 68500 Last 100 episodes mean score: 8.69
# 68600 Last 100 episodes mean score: 8.62
# 68700 Last 100 episodes mean score: 8.58
# 68800 Last 100 episodes mean score: 8.58
# 68900 Last 100 episodes mean score: 8.71
# 69000 Last 100 episodes mean score: 8.65
# 69100 Last 100 episodes mean score: 8.79
# 69200 Last 100 episodes mean score: 8.84
# 69300 Last 100 episodes mean score: 8.75
# 69400 Last 100 episodes mean score: 8.61
# 69500 Last 100 episodes mean score: 8.55
# 69600 Last 100 episodes mean score: 8.53
# 69700 Last 100 episodes mean score: 8.72
# 69800 Last 100 episodes mean score: 8.65
# 69900 Last 100 episodes mean score: 8.57
# 70000 Last 100 episodes mean score: 8.71
# 70100 Last 100 episodes mean score: 8.67
# 70200 Last 100 episodes mean score: 8.49
# 70300 Last 100 episodes mean score: 8.49
# 70400 Last 100 episodes mean score: 8.65
# 70500 Last 100 episodes mean score: 8.44
# 70600 Last 100 episodes mean score: 8.65
# 70700 Last 100 episodes mean score: 8.66
# 70800 Last 100 episodes mean score: 8.48
# 70900 Last 100 episodes mean score: 8.56
# 71000 Last 100 episodes mean score: 8.6
# 71100 Last 100 episodes mean score: 8.71
# 71200 Last 100 episodes mean score: 8.7
# 71300 Last 100 episodes mean score: 8.79
# 71400 Last 100 episodes mean score: 8.57
# 71500 Last 100 episodes mean score: 8.85
# 71600 Last 100 episodes mean score: 8.56
# 71700 Last 100 episodes mean score: 8.83
# 71800 Last 100 episodes mean score: 8.5
# 71900 Last 100 episodes mean score: 8.69
# 72000 Last 100 episodes mean score: 8.78
# 72100 Last 100 episodes mean score: 8.77
# 72200 Last 100 episodes mean score: 8.78
# 72300 Last 100 episodes mean score: 8.68
# 72400 Last 100 episodes mean score: 8.42
# 72500 Last 100 episodes mean score: 8.61
# 72600 Last 100 episodes mean score: 8.51
# 72700 Last 100 episodes mean score: 8.66
# 72800 Last 100 episodes mean score: 8.61
# 72900 Last 100 episodes mean score: 8.44
# 73000 Last 100 episodes mean score: 8.48
# 73100 Last 100 episodes mean score: 8.46
# 73200 Last 100 episodes mean score: 8.55
# 73300 Last 100 episodes mean score: 8.57
# 73400 Last 100 episodes mean score: 8.67
# 73500 Last 100 episodes mean score: 8.72
# 73600 Last 100 episodes mean score: 8.53
# 73700 Last 100 episodes mean score: 8.79
# 73800 Last 100 episodes mean score: 8.72
# 73900 Last 100 episodes mean score: 8.61
# 74000 Last 100 episodes mean score: 8.63
# 74100 Last 100 episodes mean score: 8.62
# 74200 Last 100 episodes mean score: 8.81
# 74300 Last 100 episodes mean score: 8.5
# 74400 Last 100 episodes mean score: 8.59
# 74500 Last 100 episodes mean score: 8.55
# 74600 Last 100 episodes mean score: 8.44
# 74700 Last 100 episodes mean score: 8.66
# 74800 Last 100 episodes mean score: 8.6
# 74900 Last 100 episodes mean score: 8.38
# 75000 Last 100 episodes mean score: 8.61
# 75100 Last 100 episodes mean score: 8.5
# 75200 Last 100 episodes mean score: 8.69
# 75300 Last 100 episodes mean score: 8.64
# 75400 Last 100 episodes mean score: 8.61
# 75500 Last 100 episodes mean score: 8.63
# 75600 Last 100 episodes mean score: 8.69
# 75700 Last 100 episodes mean score: 8.68
# 75800 Last 100 episodes mean score: 8.6
# 75900 Last 100 episodes mean score: 8.64
# 76000 Last 100 episodes mean score: 8.94
# 76100 Last 100 episodes mean score: 8.62
# 76200 Last 100 episodes mean score: 8.57
# 76300 Last 100 episodes mean score: 8.75
# 76400 Last 100 episodes mean score: 8.53
# 76500 Last 100 episodes mean score: 8.67
# 76600 Last 100 episodes mean score: 8.77
# 76700 Last 100 episodes mean score: 8.72
# 76800 Last 100 episodes mean score: 8.62
# 76900 Last 100 episodes mean score: 8.49
# 77000 Last 100 episodes mean score: 8.73
# 77100 Last 100 episodes mean score: 8.35
# 77200 Last 100 episodes mean score: 8.66
# 77300 Last 100 episodes mean score: 8.44
# 77400 Last 100 episodes mean score: 8.67
# 77500 Last 100 episodes mean score: 8.67
# 77600 Last 100 episodes mean score: 8.57
# 77700 Last 100 episodes mean score: 8.8
# 77800 Last 100 episodes mean score: 8.64
# 77900 Last 100 episodes mean score: 8.56
# 78000 Last 100 episodes mean score: 8.48
# 78100 Last 100 episodes mean score: 8.52
# 78200 Last 100 episodes mean score: 8.72
# 78300 Last 100 episodes mean score: 8.59
# 78400 Last 100 episodes mean score: 8.62
# 78500 Last 100 episodes mean score: 8.76
# 78600 Last 100 episodes mean score: 8.51
# 78700 Last 100 episodes mean score: 8.65
# 78800 Last 100 episodes mean score: 8.51
# 78900 Last 100 episodes mean score: 8.45
# 79000 Last 100 episodes mean score: 8.55
# 79100 Last 100 episodes mean score: 8.54
# 79200 Last 100 episodes mean score: 8.63
# 79300 Last 100 episodes mean score: 8.67
# 79400 Last 100 episodes mean score: 8.59
# 79500 Last 100 episodes mean score: 8.64
# 79600 Last 100 episodes mean score: 8.5
# 79700 Last 100 episodes mean score: 8.59
# 79800 Last 100 episodes mean score: 8.66
# 79900 Last 100 episodes mean score: 8.62
# 80000 Last 100 episodes mean score: 8.67
# 80100 Last 100 episodes mean score: 8.67
# 80200 Last 100 episodes mean score: 8.71
# 80300 Last 100 episodes mean score: 8.58
# 80400 Last 100 episodes mean score: 8.7
# 80500 Last 100 episodes mean score: 8.62
# 80600 Last 100 episodes mean score: 8.85
# 80700 Last 100 episodes mean score: 8.74
# 80800 Last 100 episodes mean score: 8.66
# 80900 Last 100 episodes mean score: 8.53
# 81000 Last 100 episodes mean score: 8.58
# 81100 Last 100 episodes mean score: 8.72
# 81200 Last 100 episodes mean score: 8.61
# 81300 Last 100 episodes mean score: 8.63
# 81400 Last 100 episodes mean score: 8.48
# 81500 Last 100 episodes mean score: 8.54
# 81600 Last 100 episodes mean score: 8.74
# 81700 Last 100 episodes mean score: 8.74
# 81800 Last 100 episodes mean score: 8.62
# 81900 Last 100 episodes mean score: 8.37
# 82000 Last 100 episodes mean score: 8.6
# 82100 Last 100 episodes mean score: 8.68
# 82200 Last 100 episodes mean score: 8.61
# 82300 Last 100 episodes mean score: 8.64
# 82400 Last 100 episodes mean score: 8.51
# 82500 Last 100 episodes mean score: 8.7
# 82600 Last 100 episodes mean score: 8.47
# 82700 Last 100 episodes mean score: 8.6
# 82800 Last 100 episodes mean score: 8.43
# 82900 Last 100 episodes mean score: 8.73
# 83000 Last 100 episodes mean score: 8.68
# 83100 Last 100 episodes mean score: 8.54
# 83200 Last 100 episodes mean score: 8.8
# 83300 Last 100 episodes mean score: 8.54
# 83400 Last 100 episodes mean score: 8.53
# 83500 Last 100 episodes mean score: 8.55
# 83600 Last 100 episodes mean score: 8.67
# 83700 Last 100 episodes mean score: 8.71
# 83800 Last 100 episodes mean score: 8.6
# 83900 Last 100 episodes mean score: 8.74
# 84000 Last 100 episodes mean score: 8.61
# 84100 Last 100 episodes mean score: 8.66
# 84200 Last 100 episodes mean score: 8.57
# 84300 Last 100 episodes mean score: 8.67
# 84400 Last 100 episodes mean score: 8.54
# 84500 Last 100 episodes mean score: 8.56
# 84600 Last 100 episodes mean score: 8.69
# 84700 Last 100 episodes mean score: 8.51
# 84800 Last 100 episodes mean score: 8.5
# 84900 Last 100 episodes mean score: 8.68
# 85000 Last 100 episodes mean score: 8.6
# 85100 Last 100 episodes mean score: 8.64
# 85200 Last 100 episodes mean score: 8.56
# 85300 Last 100 episodes mean score: 8.51
# 85400 Last 100 episodes mean score: 8.72
# 85500 Last 100 episodes mean score: 8.57
# 85600 Last 100 episodes mean score: 8.67
# 85700 Last 100 episodes mean score: 8.55
# 85800 Last 100 episodes mean score: 8.52
# 85900 Last 100 episodes mean score: 8.62
# 86000 Last 100 episodes mean score: 8.45
# 86100 Last 100 episodes mean score: 8.7
# 86200 Last 100 episodes mean score: 8.54
# 86300 Last 100 episodes mean score: 8.7
# 86400 Last 100 episodes mean score: 8.58
# 86500 Last 100 episodes mean score: 8.55
# 86600 Last 100 episodes mean score: 8.57
# 86700 Last 100 episodes mean score: 8.52
# 86800 Last 100 episodes mean score: 8.45
# 86900 Last 100 episodes mean score: 8.59
# 87000 Last 100 episodes mean score: 8.7
# 87100 Last 100 episodes mean score: 8.39
# 87200 Last 100 episodes mean score: 8.51
# 87300 Last 100 episodes mean score: 8.53
# 87400 Last 100 episodes mean score: 8.62
# 87500 Last 100 episodes mean score: 8.8
# 87600 Last 100 episodes mean score: 8.5
# 87700 Last 100 episodes mean score: 8.75
# 87800 Last 100 episodes mean score: 8.59
# 87900 Last 100 episodes mean score: 8.69
# 88000 Last 100 episodes mean score: 8.75
# 88100 Last 100 episodes mean score: 8.72
# 88200 Last 100 episodes mean score: 8.75
# 88300 Last 100 episodes mean score: 8.7
# 88400 Last 100 episodes mean score: 8.66
# 88500 Last 100 episodes mean score: 8.63
# 88600 Last 100 episodes mean score: 8.79
# 88700 Last 100 episodes mean score: 8.63
# 88800 Last 100 episodes mean score: 8.38
# 88900 Last 100 episodes mean score: 8.54
# 89000 Last 100 episodes mean score: 8.69
# 89100 Last 100 episodes mean score: 8.62
# 89200 Last 100 episodes mean score: 8.71
# 89300 Last 100 episodes mean score: 8.66
# 89400 Last 100 episodes mean score: 8.55
# 89500 Last 100 episodes mean score: 8.7
# 89600 Last 100 episodes mean score: 8.52
# 89700 Last 100 episodes mean score: 8.64
# 89800 Last 100 episodes mean score: 8.46
# 89900 Last 100 episodes mean score: 8.61
# 90000 Last 100 episodes mean score: 8.39
# 90100 Last 100 episodes mean score: 8.62
# 90200 Last 100 episodes mean score: 8.57
# 90300 Last 100 episodes mean score: 8.63
# 90400 Last 100 episodes mean score: 8.73
# 90500 Last 100 episodes mean score: 8.74
# 90600 Last 100 episodes mean score: 8.56
# 90700 Last 100 episodes mean score: 8.77
# 90800 Last 100 episodes mean score: 8.47
# 90900 Last 100 episodes mean score: 8.76
# 91000 Last 100 episodes mean score: 8.64
# 91100 Last 100 episodes mean score: 8.63
# 91200 Last 100 episodes mean score: 8.78
# 91300 Last 100 episodes mean score: 8.56
# 91400 Last 100 episodes mean score: 8.64

# %%
#OK

#Utilise B et L
function Generate_subnetwork_t(Input::Int64,
                               Output::Int64,
                               lt::Int64)
    if lt==1
        return [Dense(Input,B,L[rand(1:10)]),Dense(B,Output,σ)]
    else
        new_subnetwork=[Dense(Input,B,L[rand(1:10)])]
        for i in 1:lt-1
            new_subnetwork=[new_subnetwork...,Dense(B,B,L[rand(1:10)])]
        end
        return [new_subnetwork...,Dense(B,Output,σ)]
    end
end
# Out:
# Generate_subnetwork_t (generic function with 1 method)

# %%
function createPlayer(dqn::DQN)
    function applyNetworks(x)
        N=length(dqn.network1)
        Ys=[]
        for i in 1:N
            current_subnetwork=dqn.network1[i]
            current_lt=length(current_subnetwork)-1
            y=current_subnetwork[1](x)
            Y=[y] 
            for j in 2:current_lt
                for k in 1:(i-1)
                    if length(Ys[k])>=j #>=j
                        y.=y.+Ys[k][j-1]
                    end
                end
                y=current_subnetwork[j](y)
                Y=[Y...,y]
            end
            y=current_subnetwork[current_lt+1](y)
            Y=[Y...,y]
            Ys=[Ys...,Y]
        end
        Ys=[Ys[i][end] for i in 1:length(Ys)]
        return sum(Ys)/N
    end
    return applyNetworks
end
# Out:
# createPlayer (generic function with 1 method)

# %%
#Ok pour tout environnement de RL a priori

#Utilise aucun parametre extérieur
function All_Models(Models,
                    x)
    l=length(Models)
    Y=[Models[1]([],x)]
    if l!=1
        for i in 2:l
                Y=[Y...,Models[i](Y,x)]
        end
    end
    Y=[Y[i][end] for i in 1:length(Y)]
    return sum(Y)/length(Models)
end
# Out:
# All_Models (generic function with 1 method)

# %%
#Fonctionne bien sur cet environnement

#Utilise aucun parametre extérieur
function Model_t(Subnetwork_t,
                 t::Int64,
                 lt::Int64)
    function Model(Y_t_minus_1,
                       x)
        y=Subnetwork_t[1](x)
        Y=[y] 
        for j in 2:lt
            for i in 1:t-1
                if length(Y_t_minus_1[i])>=j
                    y.=y.+Y_t_minus_1[i][j-1]
                end
            end
            y=Subnetwork_t[j](y)
            Y=[Y...,y]
        end
        y=Subnetwork_t[lt+1](y)
        Y=[Y...,y]
        return Y
    end
    return Model
end
# Out:
# Model_t (generic function with 1 method)

# %%
function action(Models,state)
    
  act_values = All_Models(Models,state)

  return Flux.argmax(act_values)
    
end
# Out:
# action (generic function with 1 method)

# %%
#OK

#Il faut changer cette fonction si on change d'environnement(petit changement)
function weakTest(Models,seeds::Int64)
    s=0
    for i in 1:seeds
        env=CartPoleEnv(;T=Float32, seed=i)
        obs=observe(env)
        current_state=get_state(obs)
        current_done=false
        while !current_done
            current_action=action(Models,current_state)
            env(current_action)
            obs=observe(env)
            current_next_state,current_reward,current_done=get_state(obs),get_reward(obs),get_terminal(obs)
            s+=current_reward
            current_state=current_next_state
        end  
    end
    return s/seeds
end
# Out:
# weakTest (generic function with 1 method)

# %%
#OK

#Nombre de candidats à changer à la main pour l'instant
function weakLearner(Input::Int64,
                     Output::Int64,
                     lt::Int64,
                     t::Int64,
                     Models,
                     seeds::Int64)
    best_value=-Inf
    selected_subnetwork=[]
    for i in 1:10
        applicant_subnetwork=Generate_subnetwork_t(Input,Output,lt)
        current_models=[Models...,Model_t(applicant_subnetwork,t,lt)]
        current_value=weakTest(current_models,seeds)
        if current_value>best_value
            best_value=current_value
            selected_subnetwork=applicant_subnetwork
        end
    end
    return selected_subnetwork,best_value
    
end
# Out:
# weakLearner (generic function with 1 method)

# %%
#Les lignes associé à models1,models2 sont laissés mais ne sont utilisés que par le weaklearner (par faignantise)

mutable struct DQN
    TRAIN::Bool
    CHANGE::Bool
    ϵ::Float64
    ϵ_DECAY::Float64
    ϵ_MIN::Float64
    BATCH_SIZE::Int64
    MEMORY
    MEM_SIZE::Int64
    STATE_SIZE::Int64
    ACTION_SIZE::Int64
    γ::Float64
    C_UPDATE::Int64
    network1
    network2
    models1
    models2
    loss
    applyNets
    applyNets2
    ps
    opt
    t
    lt
    
    # attention network1 = [network]
    function DQN(ϵ_DECAY::Float64, ϵ_MIN::Float64,BATCH_SIZE::Int64,MEM_SIZE::Int64,STATE_SIZE::Int64,
            
                 ACTION_SIZE::Int64,γ::Float64,C_UPDATE::Int64,network1,t::Int64,lt::Int64)
        network2=deepcopy(network1)
        models1=[Model_t(network1[end],t,lt)]
        models2=[Model_t(network2[end],t,lt)]
        function applyNetworks(x)
            N=length(network1)
            Ys=[]
            for i in 1:N
                current_subnetwork=network1[i]
                current_lt=length(current_subnetwork)-1
                y=current_subnetwork[1](x)
                Y=[y] 
                for j in 2:current_lt
                    for k in 1:i-1
                        if length(Ys[k])>j #>=j
                            y.=y.+Ys[k][j-1]
                        end
                    end
                    y=current_subnetwork[j](y)
                    Y=[Y...,y]
                end
                y=current_subnetwork[current_lt+1](y)
                Y=[Y...,y]
                Ys=[Ys...,Y]
            end
            Ys=[Ys[i][end] for i in 1:length(Ys)]
            return sum(Ys)/N
        end
        applyNets=applyNetworks
        loss(x,y)=Flux.mse(applyNets(x),y)
        #loss(x,y)=Flux.mse(x,y)
        ps=Flux.params(network1[end]...)
        
        new(true, true, 1.0f0, ϵ_DECAY, ϵ_MIN, BATCH_SIZE, [], MEM_SIZE, STATE_SIZE, ACTION_SIZE,γ,C_UPDATE,network1,
            
            network2, models1,models2,loss,applyNetworks,applyNetworks, ps, ADAM(0.0001, (0.9, 0.999)),t,lt)
    end
    
end

# %%
function copy!(iter::Int64, dqn::DQN)
    if iter%dqn.C_UPDATE==0
        dqn.network2=deepcopy(dqn.network1)
        #if length(dqn.models2)>1
          #  dqn.models2=[dqn.models2[1:end-1]...,Model_t(dqn.network2[end],dqn.t,dqn.lt)]
       #else
            #dqn.models2=[Model_t(dqn.network2[end],dqn.t,dqn.lt)]
       # end
        function applyNetworks2(x)
            N=length(dqn.network2)
            Ys=[]
            for i in 1:N
                current_subnetwork=dqn.network2[i]
                current_lt=length(current_subnetwork)-1
                y=current_subnetwork[1](x)
                Y=[y] 
                for j in 2:current_lt
                    for k in 1:(i-1)
                        if length(Ys[k])>=j #>=j
                            y.=y.+Ys[k][j-1]
                        end
                    end
                    y=current_subnetwork[j](y)
                    Y=[Y...,y]
                end
                y=current_subnetwork[current_lt+1](y)
                Y=[Y...,y]
                Ys=[Ys...,Y]
            end
            Ys=[Ys[i][end] for i in 1:length(Ys)]
            return sum(Ys)/N
        end
        dqn.applyNets2=applyNetworks2
    end
end
# Out:
# copy! (generic function with 1 method)

# %%
function change(dqn::DQN,network,t,lt)
    dqn.network1=network
    dqn.network2=deepcopy(dqn.network1)
    dqn.models1=[dqn.models1...,Model_t(dqn.network1[end],t,lt)]
    dqn.models2=[dqn.models2...,Model_t(dqn.network2[end],t,lt)]
    dqn.ps=Flux.params(dqn.network1[end]...)
    dqn.t=t
    dqn.lt=lt
    dqn.applyNets=createPlayer(dqn)
    current_loss(x,y)=Flux.mse(dqn.applyNets(x),y)
    dqn.loss=current_loss
end
# Out:
# change (generic function with 1 method)

# %%
function action(dqn::DQN,state::Array{Float32,1})
  if rand() <= dqn.ϵ && dqn.TRAIN    
    return rand(1:dqn.ACTION_SIZE)
  end
  act_values = dqn.applyNets(state)
  return Flux.argmax(act_values)
end
# Out:
# action (generic function with 2 methods)

# %%
#OK
function update_ϵ!(dqn::DQN)
    x = dqn.ϵ*dqn.ϵ_DECAY
    if x < dqn.ϵ_MIN && dqn.CHANGE
        dqn.ϵ=dqn.ϵ_MIN
        dqn.CHANGE=false 
    elseif dqn.CHANGE
        dqn.ϵ = x 
    end
end
# Out:
# update_ϵ! (generic function with 1 method)

# %%
#OK
function act(action::Int64, env)
    env(action)
    obs=observe(env)
    get_state(obs), get_reward(obs), get_terminal(obs)
end
# Out:
# act (generic function with 1 method)

# %%
#OK    
function remember!(dqn::DQN,state::Array{Float32,1}, action::Int64, reward::Float32, next_state::Array{Float32,1}, done::Bool)
  if length(dqn.MEMORY) == dqn.MEM_SIZE
    deleteat!(dqn.MEMORY, 1)
  end
  push!(dqn.MEMORY, (state, action, reward, next_state, done))
end
# Out:
# remember! (generic function with 1 method)

# %%
function replay!(dqn::DQN)
    batch_size = min(dqn.BATCH_SIZE, length(dqn.MEMORY))
    minibatch = sample(dqn.MEMORY, batch_size, replace = false)
    x = []
    y = []
    for (iter, (state, action, reward, next_state, done)) in enumerate(minibatch)
        target = reward
        if !done
            target += dqn.γ * maximum(All_Models(dqn.models2,next_state))
        end
        target_f = dqn.applyNets(state)
        target_f[action] = target
        push!(x,state)
        push!(y,target_f)
    end
    Flux.train!(dqn.loss,dqn.ps, zip(x,y), dqn.opt)
end
# Out:
# replay! (generic function with 1 method)

# %%
function episode!(dqn::DQN, env)
    obs_ini=observe(env)
    current_state=get_state(obs_ini)
    total_reward=0
    i = 0
    while true
        current_action=action(dqn,current_state) #(changé)
        current_next_state,current_reward,current_done=act(current_action,env)
        total_reward+=current_reward
        remember!(dqn, current_state, current_action, current_reward, current_next_state, current_done)
        current_state=current_next_state
        #replay!(dqn) (changé)
        update_ϵ!(dqn)
        i+=1
        copy!(i,dqn) #(changé)
        if current_done  
            break   
        end   
    end
    total_reward
end
# Out:
# episode! (generic function with 1 method)

# %%
#Run DQN algorithm

function main_DQN(dqn::DQN, env)
    e=1
    scores = [0]
    while true #sum(scores)<10000
      reset!(env)
      total_reward = episode!(dqn,env)
      push!(scores, total_reward)
      replay!(dqn) 
      if e % 100 == 0 && e >= 100
        last_100_mean = mean(scores[end-99:end])
        println("$e Last 100 episodes mean score: $last_100_mean")
        if last_100_mean > 195 
          println("\nProblem solved!")
          #break
        end
      end
      e += 1
    end
    mean(scores)
end
# Out:
# main_DQN (generic function with 1 method)
